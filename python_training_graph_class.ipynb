# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

import torch
from torch_geometric.utils import from_networkx
from ipaddress import IPv4Address
import random
import logging
from torch_geometric.loader import DataLoader
import pickle

# %% [markdown]
# # Train Graph

# %% [markdown]
# ### Load Dataset

# %%
filename = 'data/dataset_python_graph.pt'
dataset = torch.load(filename, weights_only=False)

# %%
import torch
from torch_geometric.datasets import TUDataset
from pprint import pprint


print(len(dataset))
data = dataset[10]  # Get the first graph object.

print()
print(data)
print('=============================================================')



# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# 11757
#
# Data(edge_index=[2, 22], feature=[6, 110], num_nodes=6, x=[6, 48], y=1)
# =============================================================
# Number of nodes: 6
# Number of edges: 22
# Average node degree: 3.67
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True

# %%
import random

random.shuffle(dataset)

# Split the dataset into training and test sets
split_ratio = 0.7
split_index = int(len(dataset) * split_ratio)
train_dataset = dataset[:split_index]
test_dataset = dataset[split_index:]




print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 8229
# Number of test graphs: 3528

# %%
ntest = len(test_dataset)
testcount = 0
testlow = 0
testhigh = 0
for t in test_dataset:
    if t.y.item() == 0:
        testcount+=1
    if t.y.item() == 1:
        testlow+=1
    if t.y.item() == 2:
        testhigh+=1

ntrain = len(train_dataset)
traincount = 0
trainlow = 0
trainhigh = 0
for t in train_dataset:
    if t.y.item() == 0:
        traincount+=1
    if t.y.item() == 1:
        trainlow+=1
    if t.y.item() == 2:
        trainhigh+=1

print('--------------Train--------------')
print(f'\033[1mPercent of low privilege compromised graphs: \033[0m{trainlow/ntrain}')
print(f'\033[1mPercent of not compromised graphs: \033[0m{traincount/ntrain}')



print('--------------Test--------------')
print(f'\033[1mPercent of low privilege compromised graphs: \033[0m{testlow/ntest}')
print(f'\033[1mPercent of not compromised graphs: \033[0m{testcount/ntest}')
# Out:
# --------------Train--------------
# Percent of low privilege compromised graphs: 0.4338315712723296
# Percent of not compromised graphs: 0.5661684287276705
# --------------Test--------------
# Percent of low privilege compromised graphs: 0.43565759637188206
# Percent of not compromised graphs: 0.5643424036281179

# %% [markdown]
# ### GCN

# %%
import torch
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.loader import DataLoader

#Specify device manually
use_gpu = True # Set to False to use CPU
device = torch.device('cuda' if use_gpu and torch.cuda.is_available() else 'cpu')

print(f"Using device: {device}")


# DataLoader (ensure `train_dataset` and `test_dataset` are loaded correctly)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

input_dim = len(train_dataset[0].x[0])

# Define the GCN model
class GCN(torch.nn.Module):
    def __init__(self, input_dim=input_dim, hidden_channels=32, invert_output=False):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(input_dim, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)
        self.sigmoid = torch.nn.Sigmoid()


    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.2, training=self.training)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]


        x = self.lin(x)
        x = self.sigmoid(x)

        return x

model = GCN(hidden_channels=32)
print(model)
# Out:
# Using device: cpu
# GCN(
#   (conv1): GCNConv(48, 32)
#   (conv2): GCNConv(32, 32)
#   (conv3): GCNConv(32, 32)
#   (lin): Linear(in_features=32, out_features=2, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
from sklearn.metrics import precision_score, recall_score


# Initialize the model, optimizer, and loss function
model = GCN(hidden_channels=64).to(device)  # Move model to GPU
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
criterion = torch.nn.CrossEntropyLoss()

losses = []  # Training losses
test_losses = []  # Test losses
accs = []  # Test accuracies
precisions = []  # Test precisions
recalls = []  # Test recalls
train_accs = []  # Training accuracies


# Define the training loop
def train():
    model.train()
    total_loss = 0

    for data in train_loader:  # Iterate in batches over the training dataset.
        data = data.to(device)  # Move batch data to GPU
        out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        total_loss += loss.item()  # Accumulate loss for this epoch.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.
    
    # Print the accuracy for the current batch
    pred = out.argmax(dim=1)  # Use the class with highest probability.
    correct = int((pred == data.y).sum())  # Check against ground-truth labels.
    acc = correct / len(data.y)  # Derive ratio of correct predictions.
    train_accs.append(acc)  # Append accuracy to the list.
    avg_loss = total_loss / len(train_loader)  # Calculate average loss for this epoch.
    losses.append(avg_loss)  # Append the average loss to the list.

# Define the testing loop
def test(loader):
    model.eval()
    correct = 0
    total_loss = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():  # Disable gradient computation during evaluation.
        for data in loader:  # Iterate in batches over the training/test dataset.
            data = data.to(device)  # Move batch data to GPU
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y)  # Compute the loss for the batch.
            total_loss += loss.item()  # Accumulate test loss.
            pred = out.argmax(dim=1)  # Use the class with highest probability.
            correct += int((pred == data.y).sum())  # Check against ground-truth labels.

            # Collect predictions and true labels for precision and recall
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(data.y.cpu().numpy())

    avg_loss = total_loss / len(loader)  # Calculate average test loss.
    test_losses.append(avg_loss)  # Append the average test loss to the list.
    acc = correct / len(loader.dataset)  # Derive ratio of correct predictions.
    accs.append(acc)  # Append accuracy to the list.

    # Compute precision and recall
    precision = precision_score(all_labels, all_preds, average='macro',zero_division=0)
    recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    precisions.append(precision)
    recalls.append(recall)

    return acc, avg_loss, precision, recall

# Training and testing loop
for epoch in range(1, 101):
    train()
    test_acc, test_loss, precision, recall = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Loss: {losses[-1]:.4f}, Test Loss: {test_loss:.4f}, Train Acc: {train_accs[-1]:.4f}, Test Acc: {test_acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}')
# Out:
# Epoch: 001, Train Loss: 0.6637, Test Loss: 0.5315, Train Acc: 0.6216, Test Acc: 0.8090, Precision: 0.8110, Recall: 0.7988
# Epoch: 002, Train Loss: 0.5234, Test Loss: 0.4229, Train Acc: 0.8108, Test Acc: 0.9036, Precision: 0.9031, Recall: 0.9005
# Epoch: 003, Train Loss: 0.4592, Test Loss: 0.3946, Train Acc: 0.9459, Test Acc: 0.9274, Precision: 0.9285, Recall: 0.9238
# Epoch: 004, Train Loss: 0.4313, Test Loss: 0.3782, Train Acc: 0.9189, Test Acc: 0.9439, Precision: 0.9454, Recall: 0.9406
# Epoch: 005, Train Loss: 0.4088, Test Loss: 0.3683, Train Acc: 0.9459, Test Acc: 0.9544, Precision: 0.9562, Recall: 0.9512
# Epoch: 006, Train Loss: 0.3974, Test Loss: 0.3627, Train Acc: 0.9730, Test Acc: 0.9555, Precision: 0.9581, Recall: 0.9518
# Epoch: 007, Train Loss: 0.3899, Test Loss: 0.3587, Train Acc: 0.9189, Test Acc: 0.9583, Precision: 0.9608, Recall: 0.9549
# Epoch: 008, Train Loss: 0.3817, Test Loss: 0.3551, Train Acc: 0.9189, Test Acc: 0.9617, Precision: 0.9639, Recall: 0.9586
# Epoch: 009, Train Loss: 0.3750, Test Loss: 0.3535, Train Acc: 0.9459, Test Acc: 0.9626, Precision: 0.9653, Recall: 0.9591
# Epoch: 010, Train Loss: 0.3718, Test Loss: 0.3519, Train Acc: 0.9459, Test Acc: 0.9640, Precision: 0.9669, Recall: 0.9605
# Epoch: 011, Train Loss: 0.3686, Test Loss: 0.3495, Train Acc: 0.9189, Test Acc: 0.9651, Precision: 0.9675, Recall: 0.9620
# Epoch: 012, Train Loss: 0.3646, Test Loss: 0.3479, Train Acc: 0.8919, Test Acc: 0.9666, Precision: 0.9690, Recall: 0.9634
# Epoch: 013, Train Loss: 0.3623, Test Loss: 0.3463, Train Acc: 0.9459, Test Acc: 0.9668, Precision: 0.9693, Recall: 0.9637
# Epoch: 014, Train Loss: 0.3582, Test Loss: 0.3453, Train Acc: 0.9730, Test Acc: 0.9680, Precision: 0.9701, Recall: 0.9651
# Epoch: 015, Train Loss: 0.3566, Test Loss: 0.3434, Train Acc: 1.0000, Test Acc: 0.9700, Precision: 0.9719, Recall: 0.9673
# Epoch: 016, Train Loss: 0.3566, Test Loss: 0.3424, Train Acc: 0.9459, Test Acc: 0.9708, Precision: 0.9728, Recall: 0.9681
# Epoch: 017, Train Loss: 0.3531, Test Loss: 0.3397, Train Acc: 0.9459, Test Acc: 0.9734, Precision: 0.9752, Recall: 0.9709
# Epoch: 018, Train Loss: 0.3515, Test Loss: 0.3386, Train Acc: 0.9730, Test Acc: 0.9753, Precision: 0.9771, Recall: 0.9730
# Epoch: 019, Train Loss: 0.3493, Test Loss: 0.3383, Train Acc: 1.0000, Test Acc: 0.9756, Precision: 0.9775, Recall: 0.9732
# Epoch: 020, Train Loss: 0.3491, Test Loss: 0.3373, Train Acc: 0.9730, Test Acc: 0.9765, Precision: 0.9785, Recall: 0.9740
# Epoch: 021, Train Loss: 0.3492, Test Loss: 0.3364, Train Acc: 1.0000, Test Acc: 0.9770, Precision: 0.9790, Recall: 0.9746
# Epoch: 022, Train Loss: 0.3492, Test Loss: 0.3366, Train Acc: 0.9730, Test Acc: 0.9768, Precision: 0.9788, Recall: 0.9743
# Epoch: 023, Train Loss: 0.3470, Test Loss: 0.3352, Train Acc: 0.9730, Test Acc: 0.9782, Precision: 0.9800, Recall: 0.9759
# Epoch: 024, Train Loss: 0.3453, Test Loss: 0.3353, Train Acc: 0.9189, Test Acc: 0.9776, Precision: 0.9795, Recall: 0.9753
# Epoch: 025, Train Loss: 0.3450, Test Loss: 0.3346, Train Acc: 0.9730, Test Acc: 0.9782, Precision: 0.9800, Recall: 0.9759
# Epoch: 026, Train Loss: 0.3449, Test Loss: 0.3352, Train Acc: 0.9730, Test Acc: 0.9776, Precision: 0.9796, Recall: 0.9752
# Epoch: 027, Train Loss: 0.3445, Test Loss: 0.3344, Train Acc: 0.9730, Test Acc: 0.9779, Precision: 0.9798, Recall: 0.9755
# Epoch: 028, Train Loss: 0.3446, Test Loss: 0.3345, Train Acc: 1.0000, Test Acc: 0.9782, Precision: 0.9801, Recall: 0.9758
# Epoch: 029, Train Loss: 0.3424, Test Loss: 0.3338, Train Acc: 0.9730, Test Acc: 0.9790, Precision: 0.9808, Recall: 0.9768
# Epoch: 030, Train Loss: 0.3431, Test Loss: 0.3345, Train Acc: 0.9189, Test Acc: 0.9782, Precision: 0.9801, Recall: 0.9758
# Epoch: 031, Train Loss: 0.3412, Test Loss: 0.3336, Train Acc: 0.9459, Test Acc: 0.9793, Precision: 0.9810, Recall: 0.9771
# Epoch: 032, Train Loss: 0.3417, Test Loss: 0.3332, Train Acc: 0.9189, Test Acc: 0.9796, Precision: 0.9813, Recall: 0.9775
# Epoch: 033, Train Loss: 0.3410, Test Loss: 0.3329, Train Acc: 1.0000, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 034, Train Loss: 0.3422, Test Loss: 0.3331, Train Acc: 0.9730, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 035, Train Loss: 0.3407, Test Loss: 0.3337, Train Acc: 0.8919, Test Acc: 0.9793, Precision: 0.9810, Recall: 0.9771
# Epoch: 036, Train Loss: 0.3397, Test Loss: 0.3329, Train Acc: 1.0000, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 037, Train Loss: 0.3397, Test Loss: 0.3328, Train Acc: 0.9730, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 038, Train Loss: 0.3397, Test Loss: 0.3325, Train Acc: 0.8919, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 039, Train Loss: 0.3398, Test Loss: 0.3327, Train Acc: 1.0000, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 040, Train Loss: 0.3399, Test Loss: 0.3329, Train Acc: 0.9459, Test Acc: 0.9796, Precision: 0.9813, Recall: 0.9775
# Epoch: 041, Train Loss: 0.3378, Test Loss: 0.3326, Train Acc: 0.9459, Test Acc: 0.9802, Precision: 0.9817, Recall: 0.9781
# Epoch: 042, Train Loss: 0.3396, Test Loss: 0.3325, Train Acc: 0.9459, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 043, Train Loss: 0.3388, Test Loss: 0.3321, Train Acc: 0.9730, Test Acc: 0.9807, Precision: 0.9822, Recall: 0.9788
# Epoch: 044, Train Loss: 0.3383, Test Loss: 0.3323, Train Acc: 1.0000, Test Acc: 0.9802, Precision: 0.9817, Recall: 0.9781
# Epoch: 045, Train Loss: 0.3385, Test Loss: 0.3305, Train Acc: 0.9730, Test Acc: 0.9830, Precision: 0.9852, Recall: 0.9806
# Epoch: 046, Train Loss: 0.3375, Test Loss: 0.3311, Train Acc: 1.0000, Test Acc: 0.9810, Precision: 0.9826, Recall: 0.9790
# Epoch: 047, Train Loss: 0.3395, Test Loss: 0.3307, Train Acc: 1.0000, Test Acc: 0.9810, Precision: 0.9827, Recall: 0.9789
# Epoch: 048, Train Loss: 0.3375, Test Loss: 0.3319, Train Acc: 0.8919, Test Acc: 0.9804, Precision: 0.9820, Recall: 0.9784
# Epoch: 049, Train Loss: 0.3379, Test Loss: 0.3319, Train Acc: 1.0000, Test Acc: 0.9807, Precision: 0.9822, Recall: 0.9788
# Epoch: 050, Train Loss: 0.3373, Test Loss: 0.3321, Train Acc: 0.9730, Test Acc: 0.9804, Precision: 0.9820, Recall: 0.9784
# Epoch: 051, Train Loss: 0.3370, Test Loss: 0.3317, Train Acc: 1.0000, Test Acc: 0.9799, Precision: 0.9815, Recall: 0.9778
# Epoch: 052, Train Loss: 0.3378, Test Loss: 0.3309, Train Acc: 0.9730, Test Acc: 0.9804, Precision: 0.9820, Recall: 0.9784
# Epoch: 053, Train Loss: 0.3370, Test Loss: 0.3307, Train Acc: 1.0000, Test Acc: 0.9813, Precision: 0.9829, Recall: 0.9793
# Epoch: 054, Train Loss: 0.3374, Test Loss: 0.3297, Train Acc: 0.9730, Test Acc: 0.9838, Precision: 0.9860, Recall: 0.9815
# Epoch: 055, Train Loss: 0.3375, Test Loss: 0.3312, Train Acc: 0.9459, Test Acc: 0.9807, Precision: 0.9822, Recall: 0.9788
# Epoch: 056, Train Loss: 0.3376, Test Loss: 0.3315, Train Acc: 1.0000, Test Acc: 0.9804, Precision: 0.9820, Recall: 0.9784
# Epoch: 057, Train Loss: 0.3364, Test Loss: 0.3313, Train Acc: 1.0000, Test Acc: 0.9810, Precision: 0.9825, Recall: 0.9791
# Epoch: 058, Train Loss: 0.3361, Test Loss: 0.3306, Train Acc: 0.9459, Test Acc: 0.9810, Precision: 0.9826, Recall: 0.9790
# Epoch: 059, Train Loss: 0.3369, Test Loss: 0.3314, Train Acc: 1.0000, Test Acc: 0.9813, Precision: 0.9827, Recall: 0.9794
# Epoch: 060, Train Loss: 0.3359, Test Loss: 0.3317, Train Acc: 0.9730, Test Acc: 0.9810, Precision: 0.9825, Recall: 0.9791
# Epoch: 061, Train Loss: 0.3356, Test Loss: 0.3314, Train Acc: 0.9459, Test Acc: 0.9810, Precision: 0.9825, Recall: 0.9791
# Epoch: 062, Train Loss: 0.3361, Test Loss: 0.3314, Train Acc: 0.9459, Test Acc: 0.9810, Precision: 0.9825, Recall: 0.9791
# Epoch: 063, Train Loss: 0.3360, Test Loss: 0.3312, Train Acc: 1.0000, Test Acc: 0.9816, Precision: 0.9829, Recall: 0.9797
# Epoch: 064, Train Loss: 0.3346, Test Loss: 0.3313, Train Acc: 0.9189, Test Acc: 0.9816, Precision: 0.9829, Recall: 0.9797
# Epoch: 065, Train Loss: 0.3358, Test Loss: 0.3292, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 066, Train Loss: 0.3353, Test Loss: 0.3287, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 067, Train Loss: 0.3357, Test Loss: 0.3290, Train Acc: 1.0000, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 068, Train Loss: 0.3352, Test Loss: 0.3310, Train Acc: 0.9459, Test Acc: 0.9816, Precision: 0.9829, Recall: 0.9797
# Epoch: 069, Train Loss: 0.3358, Test Loss: 0.3306, Train Acc: 0.9459, Test Acc: 0.9816, Precision: 0.9829, Recall: 0.9797
# Epoch: 070, Train Loss: 0.3348, Test Loss: 0.3291, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 071, Train Loss: 0.3353, Test Loss: 0.3296, Train Acc: 1.0000, Test Acc: 0.9836, Precision: 0.9853, Recall: 0.9815
# Epoch: 072, Train Loss: 0.3341, Test Loss: 0.3290, Train Acc: 1.0000, Test Acc: 0.9838, Precision: 0.9857, Recall: 0.9818
# Epoch: 073, Train Loss: 0.3343, Test Loss: 0.3290, Train Acc: 1.0000, Test Acc: 0.9838, Precision: 0.9857, Recall: 0.9818
# Epoch: 074, Train Loss: 0.3342, Test Loss: 0.3285, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 075, Train Loss: 0.3334, Test Loss: 0.3285, Train Acc: 1.0000, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 076, Train Loss: 0.3351, Test Loss: 0.3291, Train Acc: 0.9459, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 077, Train Loss: 0.3357, Test Loss: 0.3286, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 078, Train Loss: 0.3332, Test Loss: 0.3294, Train Acc: 0.9730, Test Acc: 0.9830, Precision: 0.9846, Recall: 0.9810
# Epoch: 079, Train Loss: 0.3342, Test Loss: 0.3295, Train Acc: 1.0000, Test Acc: 0.9830, Precision: 0.9846, Recall: 0.9810
# Epoch: 080, Train Loss: 0.3340, Test Loss: 0.3285, Train Acc: 1.0000, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 081, Train Loss: 0.3339, Test Loss: 0.3284, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 082, Train Loss: 0.3337, Test Loss: 0.3293, Train Acc: 0.9730, Test Acc: 0.9838, Precision: 0.9856, Recall: 0.9818
# Epoch: 083, Train Loss: 0.3342, Test Loss: 0.3286, Train Acc: 0.9730, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 084, Train Loss: 0.3338, Test Loss: 0.3285, Train Acc: 1.0000, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 085, Train Loss: 0.3348, Test Loss: 0.3286, Train Acc: 1.0000, Test Acc: 0.9847, Precision: 0.9868, Recall: 0.9824
# Epoch: 086, Train Loss: 0.3334, Test Loss: 0.3288, Train Acc: 1.0000, Test Acc: 0.9844, Precision: 0.9865, Recall: 0.9822
# Epoch: 087, Train Loss: 0.3340, Test Loss: 0.3284, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 088, Train Loss: 0.3339, Test Loss: 0.3285, Train Acc: 0.9730, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 089, Train Loss: 0.3334, Test Loss: 0.3285, Train Acc: 1.0000, Test Acc: 0.9847, Precision: 0.9866, Recall: 0.9826
# Epoch: 090, Train Loss: 0.3327, Test Loss: 0.3285, Train Acc: 1.0000, Test Acc: 0.9847, Precision: 0.9866, Recall: 0.9826
# Epoch: 091, Train Loss: 0.3341, Test Loss: 0.3285, Train Acc: 0.9730, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 092, Train Loss: 0.3335, Test Loss: 0.3284, Train Acc: 1.0000, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 093, Train Loss: 0.3342, Test Loss: 0.3282, Train Acc: 0.9189, Test Acc: 0.9847, Precision: 0.9867, Recall: 0.9825
# Epoch: 094, Train Loss: 0.3339, Test Loss: 0.3285, Train Acc: 0.8919, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 095, Train Loss: 0.3328, Test Loss: 0.3287, Train Acc: 1.0000, Test Acc: 0.9844, Precision: 0.9865, Recall: 0.9822
# Epoch: 096, Train Loss: 0.3330, Test Loss: 0.3287, Train Acc: 1.0000, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 097, Train Loss: 0.3338, Test Loss: 0.3286, Train Acc: 1.0000, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 098, Train Loss: 0.3324, Test Loss: 0.3286, Train Acc: 1.0000, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 099, Train Loss: 0.3343, Test Loss: 0.3285, Train Acc: 0.9730, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823
# Epoch: 100, Train Loss: 0.3335, Test Loss: 0.3286, Train Acc: 1.0000, Test Acc: 0.9844, Precision: 0.9863, Recall: 0.9823

# %% [markdown]
# ## Graphs

# %%
# Plot the loss curve
plt.plot(range(1, 101), losses, label='Training Loss')
plt.plot(range(1,101), test_losses, label='Test Loss')

plt.xlabel('Epoch')
plt.legend()
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.show()

# %%
plt.plot(range(1, 101), accs, label='Test accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.ylabel('Accuracy')
plt.title('Accuracy Curves')

plt.show()

# %%
plt.plot(range(1, 101), precisions, label='Precision')
plt.plot(range(1, 101), recalls, label='Recall')
plt.xlabel('Epoch')
plt.legend()
plt.ylabel('Precision/Recall')
plt.title('Precision and Recall Curves')
plt.show()
